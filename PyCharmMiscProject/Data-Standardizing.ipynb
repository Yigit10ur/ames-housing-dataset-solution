# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
eng_df = pd.read_csv('eng_df.csv')

# %%
eng_df
# Out:
#       Unnamed: 0.1  Unnamed: 0    Id  MSSubClass MSZoning  LotFrontage  \
# 0                0           0     1          60       RL         65.0
# 1                1           1     2          20       RL         80.0
# 2                2           2     3          60       RL         68.0
# 3                3           3     4          70       RL         60.0
# 4                4           4     5          60       RL         84.0
# ...            ...         ...   ...         ...      ...          ...
# 1455          1455        1455  1456          60       RL         62.0
# 1456          1456        1456  1457          20       RL         85.0
# 1457          1457        1457  1458          70       RL         66.0
# 1458          1458        1458  1459          20       RL         68.0
# 1459          1459        1459  1460          20       RL         75.0
#
#       LotArea Street LotShape LandContour  ... ExterCond_mapped  \
# 0        8450   Pave      Reg         Lvl  ...                3
# 1        9600   Pave      Reg         Lvl  ...                3
# 2       11250   Pave      IR1         Lvl  ...                3
# 3        9550   Pave      IR1         Lvl  ...                3
# 4       14260   Pave      IR1         Lvl  ...                3
# ...       ...    ...      ...         ...  ...              ...
# 1455     7917   Pave      Reg         Lvl  ...                3
# 1456    13175   Pave      Reg         Lvl  ...                3
# 1457     9042   Pave      Reg         Lvl  ...                4
# 1458     9717   Pave      Reg         Lvl  ...                3
# 1459     9937   Pave      Reg         Lvl  ...                3
#
#      BsmtQual_mapped BsmtCond_mapped BsmtExposure_mapped LotShape_mapped  \
# 0                  4               3                   1               4
# 1                  4               3                   4               4
# 2                  4               3                   2               3
# 3                  3               4                   1               3
# 4                  4               3                   3               3
# ...              ...             ...                 ...             ...
# 1455               4               3                   1               4
# 1456               4               3                   1               4
# 1457               3               4                   1               4
# 1458               3               3                   2               4
# 1459               3               3                   1               4
#
#      HouseAge RemodAge GarageAge  TotalYears  HasGarage
# 0           5        5       5.0           5          1
# 1          31       31      31.0          31          1
# 2           7        6       7.0           6          1
# 3          91       36       8.0          36          1
# 4           8        8       8.0           8          1
# ...       ...      ...       ...         ...        ...
# 1455        8        7       8.0           7          1
# 1456       32       22      32.0          22          1
# 1457       69        4      69.0           4          1
# 1458       60       14      60.0          14          1
# 1459       43       43      43.0          43          1
#
# [1460 rows x 115 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_train = eng_df.drop('SalePrice',axis=1)
y_train = eng_df['SalePrice']

# %%
scaler = StandardScaler()
